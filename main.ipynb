# %%
from searching_algorithms import *

# %%
tube_graph = load_graph_from_csv('dataset/tubedata.csv')

# %%
tube_graph.nodes
# Out:
# NodeView(('"Harrow & Wealdstone"', '"Kenton"', '"South Kenton"', '"North Wembley"', '"Wembley Central"', '"Stonebridge Park"', '"Harlesden"', '"Willesden Junction"', '"Kensal Green"', '"Queen\'s Park"', '"Kilburn Park"', '"Maida Vale"', '"Warwick Avenue"', '"Paddington"', '"Edgware Road"', '"Marylebone"', '"Baker Street"', '"Regent\'s Park"', '"Oxford Circus"', '"Piccadilly Circus"', '"Charing Cross"', '"Embankment"', '"Waterloo"', '"Lambeth North"', '"Elephant & Castle"', '"West Ruislip"', '"Ruislip Gardens"', '"South Ruislip"', '"Northolt"', '"Greenford"', '"Perivale"', '"Hanger Lane"', '"North Acton"', '"Ealing Broadway"', '"West Acton"', '"East Acton"', '"White City"', '"Shepherd\'s Bush"', '"Holland Park"', '"Notting Hill Gate"', '"Queensway"', '"Lancaster Gate"', '"Marble Arch"', '"Bond Street"', '"Tottenham Court Road"', '"Holborn"', '"Chancery Lane"', '"St. Paul\'s"', '"Bank/Monument"', '"Liverpool Street"', '"Bethnal Green"', '"Mile End"', '"Stratford"', '"Leyton"', '"Leyton
# ...

# %%
show_weighted_graph(tube_graph, 2500, 10, (50, 50))

# %%
dfs_path = dfs(tube_graph, '"Canada Water"', '"Stratford"', 0)
print(dfs_path)
bfs_path = bfs(tube_graph, '"Canada Water"', '"Stratford"', 0)
print(bfs_path)
ucs_path = ucs(tube_graph, '"Canada Water"', '"Stratford"', 'avg_time')
print(ucs_path)
# Out:
# DFS Nodes visited:  286
# DFS Solution cost:  8
# ['"Canada Water"', '"Canary Wharf"', '"North Greenwich"', '"Canning Town"', '"West Ham"', '"Bromley-by-Bow"', '"Bow Road"', '"Mile End"', '"Stratford"']
# BFS Nodes visited:  49
# BFS Solution cost:  5
# ['"Canada Water"', '"Canary Wharf"', '"North Greenwich"', '"Canning Town"', '"West Ham"', '"Stratford"']
# Nodes visited:  271
# Nodes to reach solution:  7
# Number of transitions between tube lines:  2
# (14.0, ['"Canada Water"', '"Rotherhithe"', '"Wapping"', '"Shadwell"', '"Whitechapel"', '"Stepney Green"', '"Mile End"', '"Stratford"'], ['"East London"', '"Hammersmith & City"', '"Central"'])

# %%
dfs_path = dfs(tube_graph, '"New Cross Gate"', '"Stepney Green"', 0)
print(dfs_path)
bfs_path = bfs(tube_graph, '"New Cross Gate"', '"Stepney Green"', 0)
print(bfs_path)
ucs_path = ucs(tube_graph, '"New Cross Gate"', '"Stepney Green"', 'avg_time')
print(ucs_path)
# Out:
# DFS Nodes visited:  24
# DFS Solution cost:  10
# ['"New Cross Gate"', '"Surrey Quays"', '"Canada Water"', '"Canary Wharf"', '"North Greenwich"', '"Canning Town"', '"West Ham"', '"Bromley-by-Bow"', '"Bow Road"', '"Mile End"', '"Stepney Green"']
# BFS Nodes visited:  27
# BFS Solution cost:  7
# ['"New Cross Gate"', '"Surrey Quays"', '"Canada Water"', '"Rotherhithe"', '"Wapping"', '"Shadwell"', '"Whitechapel"', '"Stepney Green"']
# Nodes visited:  271
# Nodes to reach solution:  7
# Number of transitions between tube lines:  1
# (14.0, ['"New Cross Gate"', '"Surrey Quays"', '"Canada Water"', '"Rotherhithe"', '"Wapping"', '"Shadwell"', '"Whitechapel"', '"Stepney Green"'], ['"East London"', '"Hammersmith & City"'])

# %%
dfs_path = dfs(tube_graph, '"Ealing Broadway"', '"South Kensington"', 0)
print(dfs_path)
bfs_path = bfs(tube_graph, '"Ealing Broadway"', '"South Kensington"', 0)
print(bfs_path)
ucs_path = ucs(tube_graph, '"Ealing Broadway"', '"South Kensington"', 'avg_time')
print(ucs_path)
# Out:
# DFS Nodes visited:  41
# DFS Solution cost:  22
# ['"Ealing Broadway"', '"Ealing Common"', '"North Ealing"', '"Park Royal"', '"Alperton"', '"Sudbury Town"', '"Sudbury Hill"', '"South Harrow"', '"Rayners Lane"', '"West Harrow"', '"Harrow-on-the-Hill"', '"Northwick Park"', '"Preston Road"', '"Wembley Park"', '"Finchley Road"', '"Swiss Cottage"', '"St. John\'s Wood"', '"Baker Street"', '"Bond Street"', '"Green Park"', '"Hyde Park Corner"', '"Knightsbridge"', '"South Kensington"']
# BFS Nodes visited:  69
# BFS Solution cost:  9
# ['"Ealing Broadway"', '"Ealing Common"', '"Acton Town"', '"Chiswick Park"', '"Turnham Green"', '"Hammersmith"', '"Barons Court"', '"Earls\' Court"', '"Gloucester Road"', '"South Kensington"']
# Nodes visited:  271
# Nodes to reach solution:  8
# Number of transitions between tube lines:  1
# ...

# %%
dfs_path = dfs(tube_graph, '"Baker Street"', '"Wembley Park"', 0)
print(dfs_path)
bfs_path = bfs(tube_graph, '"Baker Street"', '"Wembley Park"', 0)
print(bfs_path)
ucs_path = ucs(tube_graph, '"Baker Street"', '"Wembley Park"', 'avg_time')
print(ucs_path)
# Out:
# DFS Nodes visited:  10
# DFS Solution cost:  7
# ['"Baker Street"', '"Finchley Road"', '"West Hampstead"', '"Kilburn"', '"Willesden Green"', '"Dollis Hill"', '"Neasden"', '"Wembley Park"']
# BFS Nodes visited:  17
# BFS Solution cost:  2
# ['"Baker Street"', '"Finchley Road"', '"Wembley Park"']
# Nodes visited:  271
# Nodes to reach solution:  2
# Number of transitions between tube lines:  0
# (13.0, ['"Baker Street"', '"Finchley Road"', '"Wembley Park"'], ['"Metropolitan"'])

# %%
middle_labyrinth = load_graph_from_json("dataset/middle_labyrinth.json")

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1UX1EjbQl7kQ9EeW26cn1ArYHgUsAJWkR)

# %%
path = a_star(middle_labyrinth, '[0,0]', '[9,9]')
print(path)
# Out:
# A* Nodes visited:  1988
# A* Solution nodes expanded:  25
# ['[0,0]', '[1,0]', '[1,1]', '[2,1]', '[2,2]', '[1,2]', '[0,2]', '[0,3]', '[1,3]', '[1,4]', '[1,5]', '[2,5]', '[2,6]', '[3,6]', '[4,6]', '[5,6]', '[5,7]', '[4,7]', '[4,8]', '[5,8]', '[5,9]', '[6,9]', '[7,9]', '[8,9]', '[9,9]']
